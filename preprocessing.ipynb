# %% [markdown]
# Import the pandas library
# Read the data company.csv in pandas

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("https://cdn-uploads.piazza.com/paste/irzzqf19kdc2cb/8ddcd64db1870214bde02f0ccc1239a7f8e929c11ca96140b3367c77777a18b3/company.csv")
data
# Out:
#      Company   Age  Salary     Place Country  Gender
# 0        TCS  20.0     NaN   Chennai   India       0
# 1    Infosys  30.0     NaN    Mumbai   India       0
# 2        TCS  35.0  2300.0  Calcutta   India       0
# 3    Infosys  40.0  3000.0     Delhi   India       0
# 4        TCS  23.0  4000.0    Mumbai   India       0
# ..       ...   ...     ...       ...     ...     ...
# 143      TCS  33.0  9024.0  Calcutta   India       1
# 144  Infosys  22.0  8787.0  Calcutta   India       1
# 145  Infosys  44.0  4034.0     Delhi   India       1
# 146      TCS  33.0  5034.0    Mumbai   India       1
# 147  Infosys  22.0  8202.0    Cochin   India       0
#
# [148 rows x 6 columns]

# %% [markdown]
# Find the dimension of given data

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148 entries, 0 to 147
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Company  140 non-null    object
#  1   Age      130 non-null    float64
#  2   Salary   124 non-null    float64
#  3   Place    134 non-null    object
#  4   Country  148 non-null    object
#  5   Gender   148 non-null    int64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 7.1+ KB

# %% [markdown]
# List down all the columns in data frame

# %%
data.columns
# Out:
# Index(['Company', 'Age', 'Salary', 'Place', 'Country', 'Gender'], dtype='object')

# %% [markdown]
# List the top 10 rows in datframe

# %%
data.head(10)
# Out:
#    Company   Age  Salary     Place Country  Gender
# 0      TCS  20.0     NaN   Chennai   India       0
# 1  Infosys  30.0     NaN    Mumbai   India       0
# 2      TCS  35.0  2300.0  Calcutta   India       0
# 3  Infosys  40.0  3000.0     Delhi   India       0
# 4      TCS  23.0  4000.0    Mumbai   India       0
# 5  Infosys   NaN  5000.0  Calcutta   India       0
# 6      TCS   NaN  6000.0   Chennai   India       1
# 7  Infosys  23.0  7000.0    Mumbai   India       1
# 8      TCS  34.0  8000.0  Calcutta   India       1
# 9      CTS  45.0  9000.0     Delhi   India       0

# %% [markdown]
# List the last 15 rows in datframe

# %%
data.tail(15)
# Out:
#                        Company   Age  Salary      Place Country  Gender
# 133                        NaN  22.0  8943.0    Chennai   India       0
# 134  Tata Consultancy Services  31.0  8345.0     Mumbai   India       0
# 135                        CTS  40.0  9284.0   Calcutta   India       1
# 136                        NaN   NaN     NaN      Delhi   India       0
# 137                        CTS  31.0  2034.0     Mumbai   India       0
# 138                        CTS  44.0  3033.0     Cochin   India       0
# 139                 Congnizant  22.0  2934.0      Noida   India       0
# 140                    Infosys  44.0  4034.0  Hyderabad   India       0
# 141                        TCS  33.0  5034.0   Calcutta   India       0
# 142            Infosys Pvt Lmt  22.0  8202.0     Mumbai   India       0
# 143                        TCS  33.0  9024.0   Calcutta   India       1
# 144                    Infosys  22.0  8787.0   Calcutta   India       1
# 145                    Infosys  44.0  4034.0      Delhi   India       1
# 146                        TCS  33.0  5034.0     Mumbai   India       1
# 147                    Infosys  22.0  8202.0     Cochin   India       0

# %% [markdown]
# Find the number of rows in dataframe

# %%
data.shape[0]
# Out:
# 148

# %% [markdown]
# Check the information of dataframe

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148 entries, 0 to 147
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Company  140 non-null    object
#  1   Age      130 non-null    float64
#  2   Salary   124 non-null    float64
#  3   Place    134 non-null    object
#  4   Country  148 non-null    object
#  5   Gender   148 non-null    int64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 7.1+ KB

# %% [markdown]
# Check the basic Statistics of Dataframe. Give your inference from the stats

# %%
data.describe()
# Out:
#               Age       Salary      Gender
# count  130.000000   124.000000  148.000000
# mean    30.484615  5312.467742    0.222973
# std     11.096640  2573.764683    0.417654
# min      0.000000  1089.000000    0.000000
# 25%     22.000000  3030.000000    0.000000
# 50%     32.500000  5000.000000    0.000000
# 75%     37.750000  8000.000000    0.000000
# max     54.000000  9876.000000    1.000000

# %% [markdown]
# Retrieve 20 to 100 rows and Company and age usig iloc

# %%
data.iloc[20:100,0:2]
# Out:
#     Company   Age
# 20      TCS  37.0
# 21  Infosys  50.0
# 22      TCS  21.0
# 23  Infosys   NaN
# 24      TCS   NaN
# ..      ...   ...
# 95  Infosys   NaN
# 96      TCS   NaN
# 97  Infosys  22.0
# 98      TCS  33.0
# 99      CTS  44.0
#
# [80 rows x 2 columns]

# %% [markdown]
# Retrieve 20 to 100 rows and Company and age usig loc

# %%
data.loc[20:100,"Company":"Age"]
# Out:
#     Company   Age
# 20      TCS  37.0
# 21  Infosys  50.0
# 22      TCS  21.0
# 23  Infosys  22.0
# 24      TCS  22.0
# ..      ...   ...
# 95  Infosys  22.0
# 96      TCS  22.0
# 97  Infosys  22.0
# 98      TCS  33.0
# 99      CTS  44.0
#
# [69 rows x 2 columns]

# %% [markdown]
# Chage the data in 100 row and Place as 'Noida'

# %%
data.rename(columns={'Place':'City'},inplace=True)

# %%
data.loc[(data.City=="Noida"),["City"]]
# Out:
#       City
# 44   Noida
# 56   Noida
# 64   Noida
# 76   Noida
# 119  Noida
# 127  Noida
# 139  Noida

# %% [markdown]
# Change the column 'Place' to 'City'

# %%
data["Company"].unique()
# Out:
# array(['TCS', 'Infosys', 'CTS', nan, 'Tata Consultancy Services',
#        'Congnizant', 'Infosys Pvt Lmt'], dtype=object)

# %%
data["Age"].unique()
# Out:
# array([20., 30., 35., 40., 23., nan, 34., 45., 18., 22., 32., 37., 50.,
#        21., 46., 36., 26., 41., 24., 25., 43., 19., 38., 51., 31., 44.,
#        33., 17.,  0., 54.])

# %%
data.describe(include='all').loc['unique', :]
# Out:
# Company      6
# Age        NaN
# Salary     NaN
# City        11
# Country      1
# Gender     NaN
# Name: unique, dtype: object

# %% [markdown]
# List down the unique data in each columns and find length of unique data

# %%
# Out:
# Company     6
# Age        29
# Salary     40
# City       11
# Country     1
# Gender      2
# dtype: int64

# %%
data.groupby("Company").sum()
# Out:
#                               Age    Salary  Gender
# Company
# CTS                        1159.0  117871.0       8
# Congnizant                   43.0    5868.0       0
# Infosys                    1207.0  212844.0       7
# Infosys Pvt Lmt              43.0   16404.0       0
# TCS                        1280.0  258186.0      16
# Tata Consultancy Services    67.0   16690.0       1

# %% [markdown]
# Rename all the possible labels of column in Company as three labels
# TCS
# CTS
# Infosys

# %%
data["Company"].replace({"Congnizant": "CTS", "Infosys Pvt Lmt": "Infosys","Tata Consultancy Services":"TCS"},inplace=True)

# %%
data.groupby("Company").sum()
# Out:
#             Age    Salary  Gender
# Company
# CTS      1202.0  123739.0       8
# Infosys  1250.0  229248.0       7
# TCS      1347.0  274876.0      17

# %% [markdown]
# Where ever you see age as 0 replace with NA
#
# ##Hint df[df.Age==20] = np.isnan

# %%
data[data.duplicated()]
# Out:
#      Company   Age  Salary      City Country  Gender
# 84       CTS  43.0     NaN    Mumbai   India       0
# 130      TCS  21.0  4824.0    Mumbai   India       0
# 131  Infosys   NaN  5835.0    Mumbai   India       0
# 144  Infosys  22.0  8787.0  Calcutta   India       1

# %% [markdown]
# Check how many duplicated data is there?

# %%
data=data.drop_duplicates()

# %% [markdown]
# Remove all duplicated rowise data

# %%
data
# Out:
#      Company   Age  Salary      City Country  Gender
# 0        TCS  20.0     NaN   Chennai   India       0
# 1    Infosys  30.0     NaN    Mumbai   India       0
# 2        TCS  35.0  2300.0  Calcutta   India       0
# 3    Infosys  40.0  3000.0     Delhi   India       0
# 4        TCS  23.0  4000.0    Mumbai   India       0
# ..       ...   ...     ...       ...     ...     ...
# 142  Infosys  22.0  8202.0    Mumbai   India       0
# 143      TCS  33.0  9024.0  Calcutta   India       1
# 145  Infosys  44.0  4034.0     Delhi   India       1
# 146      TCS  33.0  5034.0    Mumbai   India       1
# 147  Infosys  22.0  8202.0    Cochin   India       0
#
# [144 rows x 6 columns]

# %% [markdown]
# Remove the column 'Country'

# %%
data.drop(columns=['Country'])
# Out:
#      Company   Age  Salary      City  Gender
# 0        TCS  20.0     NaN   Chennai       0
# 1    Infosys  30.0     NaN    Mumbai       0
# 2        TCS  35.0  2300.0  Calcutta       0
# 3    Infosys  40.0  3000.0     Delhi       0
# 4        TCS  23.0  4000.0    Mumbai       0
# ..       ...   ...     ...       ...     ...
# 142  Infosys  22.0  8202.0    Mumbai       0
# 143      TCS  33.0  9024.0  Calcutta       1
# 145  Infosys  44.0  4034.0     Delhi       1
# 146      TCS  33.0  5034.0    Mumbai       1
# 147  Infosys  22.0  8202.0    Cochin       0
#
# [144 rows x 5 columns]

# %% [markdown]
# Remove the row number 137

# %%
data.drop(137)
# Out:
#      Company   Age  Salary      City Country  Gender
# 0        TCS  20.0     NaN   Chennai   India       0
# 1    Infosys  30.0     NaN    Mumbai   India       0
# 2        TCS  35.0  2300.0  Calcutta   India       0
# 3    Infosys  40.0  3000.0     Delhi   India       0
# 4        TCS  23.0  4000.0    Mumbai   India       0
# ..       ...   ...     ...       ...     ...     ...
# 142  Infosys  22.0  8202.0    Mumbai   India       0
# 143      TCS  33.0  9024.0  Calcutta   India       1
# 145  Infosys  44.0  4034.0     Delhi   India       1
# 146      TCS  33.0  5034.0    Mumbai   India       1
# 147  Infosys  22.0  8202.0    Cochin   India       0
#
# [143 rows x 6 columns]

# %% [markdown]
# Find number of each labels in Company

# %%
data.count()
# Out:
# Company    136
# Age        127
# Salary     121
# City       130
# Country    144
# Gender     144
# dtype: int64

# %% [markdown]
# Find number of each labels in City

# %%
data.groupby("City").count()
# Out:
#             Company  Age  Salary  Country  Gender
# City
# Bhopal            1    1       1        1       1
# Calcutta         30   28      27       32      32
# Chennai          13   10      11       14      14
# Cochin           13   11      12       13      13
# Delhi            13   13      12       14      14
# Hyderabad         7    7       6        8       8
# Mumbai           33   31      27       34      34
# Nagpur            1    1       1        1       1
# Noida             7    8       7        8       8
# Podicherry        3    3       3        3       3
# Pune              2    2       1        2       2

# %% [markdown]
# Find Number of Null Values in each column

# %%
data.isna().sum()
# Out:
# Company     8
# Age        17
# Salary     23
# City       14
# Country     0
# Gender      0
# dtype: int64

# %% [markdown]
# Remove all Null values in Salary

# %%
data=data.dropna(axis=0, subset=['Salary'])

# %% [markdown]
# Replace the Null values in Comapany with mode

# %%
data.fillna(data.mode().iloc[0],inplace=True)

# %% [markdown]
# Replace the null value in Salary with median

# %%
data[data["Salary"].isnull()]
# Out:
# Empty DataFrame
# Columns: [Company, Age, Salary, City, Country, Gender]
# Index: []

# %%
data[data["Age"].isna()]
# Out:
# Empty DataFrame
# Columns: [Company, Age, Salary, City, Country, Gender]
# Index: []

# %%
# Out:
#      Company   Age  Salary       City Country  Gender
# 21   Infosys  50.0  3184.0      Delhi   India       0
# 32   Infosys  45.0  4034.0   Calcutta   India       0
# 39   Infosys  41.0  3000.0     Mumbai   India       0
# 50   Infosys  41.0  3000.0    Chennai   India       0
# 57   Infosys  51.0  3184.0  Hyderabad   India       0
# 68   Infosys  43.0  4034.0     Mumbai   India       0
# 75   Infosys  44.0  3000.0     Cochin   India       0
# 86   Infosys  41.0  3000.0      Delhi   India       0
# 93   Infosys  54.0  3184.0     Mumbai   India       0
# 104  Infosys  44.0  4034.0      Delhi   India       0
# 122  Infosys  44.0  3234.0     Mumbai   India       0
# 129  Infosys  50.0  3184.0   Calcutta   India       0
# 138      CTS  44.0  3033.0     Cochin   India       0
# 140  Infosys  44.0  4034.0  Hyderabad   India       0
# 145  Infosys  44.0  4034.0      Delhi   India       1

# %% [markdown]
# Replace the null value in age with mean

# %% [markdown]
# Filter the data with age>40 and Salary<5000

# %%
data.loc[(data.Age >40)&(data.Salary<5000)]
# Out:
#      Company   Age  Salary       City Country  Gender
# 21   Infosys  50.0  3184.0      Delhi   India       0
# 32   Infosys  45.0  4034.0   Calcutta   India       0
# 39   Infosys  41.0  3000.0     Mumbai   India       0
# 50   Infosys  41.0  3000.0    Chennai   India       0
# 57   Infosys  51.0  3184.0  Hyderabad   India       0
# 68   Infosys  43.0  4034.0     Mumbai   India       0
# 75   Infosys  44.0  3000.0     Cochin   India       0
# 86   Infosys  41.0  3000.0      Delhi   India       0
# 93   Infosys  54.0  3184.0     Mumbai   India       0
# 104  Infosys  44.0  4034.0      Delhi   India       0
# 122  Infosys  44.0  3234.0     Mumbai   India       0
# 129  Infosys  50.0  3184.0   Calcutta   India       0
# 138      CTS  44.0  3033.0     Cochin   India       0
# 140  Infosys  44.0  4034.0  Hyderabad   India       0
# 145  Infosys  44.0  4034.0      Delhi   India       1

# %% [markdown]
# Draw an histogram chart for age, Salary

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
data.plot('Age','Salary',kind = 'hist',bins=5)

#plt.hist(data, bins = 1)
#plt.xlabel('Salary')
#plt.ylabel('Age')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# Draw the pie chart for place and Company

# %%
data.groupby(['City']).sum().plot(kind='pie', y='Salary')
# Out:
# <AxesSubplot:ylabel='Salary'>

# %%
data.groupby(['Company']).sum().plot(kind='pie', y='Salary')
# Out:
# <AxesSubplot:ylabel='Salary'>

# %% [markdown]
# Find the mean, count, median of salary with repective to the place

# %%
#data.groupby('City').agg({'Salary':'count','Salary':'mean','Salary':'median'})
data.groupby('City').Salary.agg(['count','mean','median']).reset_index()
# Out:
#           City  count         mean  median
# 0       Bhopal      1  7000.000000  7000.0
# 1     Calcutta     40  5707.675000  5034.0
# 2      Chennai     11  6115.090909  6000.0
# 3       Cochin     12  5053.000000  5017.0
# 4        Delhi     12  4768.833333  3609.0
# 5    Hyderabad      6  4382.833333  3609.0
# 6       Mumbai     27  4833.740741  4034.0
# 7       Nagpur      1  8000.000000  8000.0
# 8        Noida      7  4387.000000  4000.0
# 9   Podicherry      3  4782.666667  3030.0
# 10        Pune      1  9000.000000  9000.0

# %% [markdown]
# Find the mean age with repective to the Company

# %%
data.groupby('Company', as_index=False).Age.mean()
# Out:
#    Company        Age
# 0      CTS  30.703704
# 1  Infosys  30.536585
# 2      TCS  27.698113
